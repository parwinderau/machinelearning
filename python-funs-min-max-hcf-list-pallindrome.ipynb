# %% [markdown]
# <a href="https://colab.research.google.com/github/parwinderau/machinelearning/blob/main/python-funs-min-max-hcf-list-pallindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=60
y=30
min=0
max=0
cf=1

########Finding max and minimum from given two numbers##############
def cal_maxmin_func(x, y):
  if x>y:
      max=x
      min=y
  else :
      min=x
      max=y
  return max,min

###########Finding min between two number###############
def cal_min_func(x, y):
  if x>y:
      max=x
      min=y
  else :
      min=x
      max=y
  return min

def cal_hcf_func(x, y):
  hcf=1
  for i in range(1, min):
    if (min % i == 0) and (max % i == 0):
      hcf=i
  return hcf  

###########List Min Element Finding#########################
def cal_list_min_func(l):
   list_min=0
   if (len(l) < 1 ):
  
     print("List is Empty. Not comparable")
     return "Error"

   if (len(l) >= 1 ):
    list_min=l[0]
    
    for x in l:
      print ("Comapre", x, list_min)
      list_min=cal_min_func(x, list_min )
   return list_min

###Printing Non Decreasing List Elements##################
def asecending_list_func(lst):
  ascend_list =[]
  while (len(lst) > 0):
    print (ascend_list)
    print ("current length of list:", len(lst))
    list_min=cal_list_min_func(lst)
    ascend_list.append(list_min)
    lst.remove(list_min)
  return  ascend_list

 


#########Calling of List related function########
mylist = [4,1,11,7,11,6, 9,8]  
print ("Our Non decreasing List is:", asecending_list_func(mylist) )
print ("Our Min value is: ", cal_list_min_func(mylist))
max, min = cal_maxmin_func (x, y)

print ("Min is ", min, "Max is ", max)


print ("HCF",cal_hcf_func(x, y))
# Out:
# []
# current length of list: 8
# Comapre 4 4
# Comapre 1 4
# Comapre 11 1
# Comapre 7 1
# Comapre 11 1
# Comapre 6 1
# Comapre 9 1
# Comapre 8 1
# [1]
# current length of list: 7
# Comapre 4 4
# Comapre 11 4
# Comapre 7 4
# Comapre 11 4
# Comapre 6 4
# Comapre 9 4
# Comapre 8 4
# [1, 4]
# current length of list: 6
# Comapre 11 11
# Comapre 7 11
# Comapre 11 7
# Comapre 6 7
# Comapre 9 6
# Comapre 8 6
# [1, 4, 6]
# current length of list: 5
# Comapre 11 11
# Comapre 7 11
# Comapre 11 7
# Comapre 9 7
# Comapre 8 7
# [1, 4, 6, 7]
# current length of list: 4
# Comapre 11 11
# Comapre 11 11
# Comapre 9 11
# Comapre 8 9
# [1, 4, 6, 7, 8]
# current length of list: 3
# Comapre 11 11
# Comapre 11 11
# Comapre 9 11
# [1, 4, 6, 7, 8, 9]
# current length of list: 2
# Comapre 11 11
# Comapre 11 11
# [1, 4, 6, 7, 8, 9, 11]
# current length of list: 1
# Comapre 11 11
# Our Non decreasing List is: [1, 4, 6, 7, 8, 9, 11, 11]
# List is Empty. Not comparable
# Our Min value is:  Error
# ...
